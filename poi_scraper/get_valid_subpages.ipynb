# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from collections import deque

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
}

MAX_SUBPAGES = 1000  # Maximum number of subpages to collect

def is_valid_url(url):
    """Check if a URL is valid and returns a 200 status code."""
    try:
        response = requests.get(url, headers=headers, timeout=5)
        print(url)
        return response.status_code == 200
    except requests.RequestException:
        return False

def should_skip_url(url):
    """Check if the URL contains patterns that we want to skip."""
    return '?' in url or '/#' in url

def get_valid_subpages_bfs(start_url, max_depth):
    """Use breadth-first search to get valid subpages within the same domain and path, up to max_depth and MAX_SUBPAGES."""
    base_domain = urlparse(start_url).netloc
    base_path = urlparse(start_url).path
    visited = set([start_url])  # Start with the initial URL as visited
    valid_links = set()
    queue = deque([(start_url, 0)])  # Queue stores (url, depth)

    while queue and len(valid_links) < MAX_SUBPAGES:
        url, depth = queue.popleft()
        
        # Stop if max_depth is reached
        if depth > max_depth:
            continue
        
        # Skip URLs containing unwanted patterns
        if should_skip_url(url):
            continue

        # Fetch and parse the page
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all subpage links
            for link in soup.find_all('a', href=True):
                full_url = urljoin(url, link['href'])
                link_domain = urlparse(full_url).netloc
                link_path = urlparse(full_url).path

                # Only consider links within the same domain and path
                if link_domain == base_domain and link_path.startswith(base_path) and full_url not in visited:
                    # Skip URLs containing unwanted patterns
                    if should_skip_url(full_url):
                        continue

                    visited.add(full_url)  # Mark as visited
                    # Check if the URL is valid and accessible
                    if is_valid_url(full_url):
                        valid_links.add(full_url)
                        queue.append((full_url, depth + 1))  # Add to queue for next level exploration

                    # Stop if we've reached MAX_SUBPAGES
                    if len(valid_links) >= MAX_SUBPAGES:
                        break

        except requests.RequestException as e:
            print(f"Error fetching {url}: {e}")
    
    return valid_links

# Entry function with max_depth parameter
def get_recursive_subpages(url, max_depth=2):
    return get_valid_subpages_bfs(url, max_depth)

# Example usage:
url = "https://www.medulinriviera.info/hr"
subpages = get_recursive_subpages(url, max_depth=3)
print(subpages)
# Out:
# https://www.medulinriviera.info/hr/
# https://www.medulinriviera.info/hr/dolazak-u-medulin/
# https://www.medulinriviera.info/hr/tourist-agencies/
# https://www.medulinriviera.info/hr/getting-around/
# https://www.medulinriviera.info/hr/klima-i-vrijeme/
# https://www.medulinriviera.info/hr/odmor-s-kucnim-ljubimcima/
# https://www.medulinriviera.info/hr/banke-novac/
# https://www.medulinriviera.info/hr/zdravlje-zdravstvene-usluge/
# https://www.medulinriviera.info/hr/wi-fi-tocke/
# https://www.medulinriviera.info/hr/korisni-telefonski-brojevi/
# https://www.medulinriviera.info/hr/home/inkluzivni-turizam/
# https://www.medulinriviera.info/hr/accommodation/hotels/
# https://www.medulinriviera.info/hr/accommodation/camping/
# https://www.medulinriviera.info/hr/accommodation/mobile-homes/
# https://www.medulinriviera.info/hr/accommodation/resorts/
# https://www.medulinriviera.info/hr/accommodation/marinas/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/
# https://www.medulinriviera.info/hr/accommodation/hostel/
# https://www.medulinriviera.info/hr/places/
# https://www.medulinriviera.info/hr/beaches/
# https://www.medulinriviera.info/hr/activities/
# https://www.medulinriviera.info/hr/attractions/
# https://www.medulinriviera.info/hr/kamenjak/
# https://www.medulinriviera.info/hr/archeological-park-vizula/
# https://www.medulinriviera.info/hr/topla-zima/
# https://www.medulinriviera.info/hr/the-magic-of-music/
# https://www.medulinriviera.info/hr/sea-treasure/
# https://www.medulinriviera.info/hr/events/
# https://www.medulinriviera.info/hr/webcam/
# https://www.medulinriviera.info/hr/activities/cycling/download/
# https://www.medulinriviera.info/hr/multimedia/brochures-multimedia/
# https://www.medulinriviera.info/hr/multimedia/
# https://www.medulinriviera.info/hr/accommodation/
# https://www.medulinriviera.info/hr/home/jesen-i-zima-na-medulin-rivieri/
# https://www.medulinriviera.info/hr/beaches/kamenjak/
# https://www.medulinriviera.info/hr/beaches/otoci/
# https://www.medulinriviera.info/hr/beaches/medulin/
# https://www.medulinriviera.info/hr/beaches/premantura/
# https://www.medulinriviera.info/hr/beaches/banjole/
# https://www.medulinriviera.info/hr/beaches/pomer-2/
# https://www.medulinriviera.info/hr/beaches/pjescana-uvala-2/
# https://www.medulinriviera.info/hr/beaches/vinkuran/
# https://www.medulinriviera.info/hr/activity/upper-kamenjak-route-no-303/
# https://www.medulinriviera.info/hr/activity/rental-center-medulin/
# https://www.medulinriviera.info/hr/activity/137-sensory-didactic-path-gradine/
# https://www.medulinriviera.info/hr/activity/gat/
# https://www.medulinriviera.info/hr/activity/aqua-life/
# https://www.medulinriviera.info/hr/activity/windsurf-station-premantura/
# https://www.medulinriviera.info/hr/gastronomy/
# https://www.medulinriviera.info/hr/navigation-maps/
# https://www.medulinriviera.info/hr/cookie-policy/
# https://www.medulinriviera.info/hr/activity/diving-center-shark/
# https://www.medulinriviera.info/hr/activity/premantura-boat-rentals-watersports/
# https://www.medulinriviera.info/hr/activity/windsurf-station-premantura-2/
# https://www.medulinriviera.info/hr/activity/bumbiste-walking-route-no-301/
# https://www.medulinriviera.info/hr/activity/the-big-blue/
# https://www.medulinriviera.info/hr/activity/windsurf-centar-premantura-2/
# https://www.medulinriviera.info/hr/accommodation/hotels/hotel-park-plaza-belvedere/
# https://www.medulinriviera.info/hr/accommodation/hotels/hotel-sensimar-medulin/
# https://www.medulinriviera.info/hr/accommodation/hotels/aparthotel-del-mar/
# https://www.medulinriviera.info/hr/accommodation/hotels/boutique-hotel-valsabbion/
# https://www.medulinriviera.info/hr/accommodation/hotels/hotel-premantura-resort/
# https://www.medulinriviera.info/hr/accommodation/hotels/arena-hotel-holiday/
# https://www.medulinriviera.info/hr/accommodation/hotels/hotel-hilde/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-arena-kazela/
# https://www.medulinriviera.info/hr/accommodation/camping/arena-one-99-glamping/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-peskera/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-piccolo/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-arena-medulin/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-centinera/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-kranjski-kamp/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-arena-indije/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-arena-runke/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-arena-stupice/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-arena-tasalera/
# https://www.medulinriviera.info/hr/accommodation/camping/kamp-diana/
# https://www.medulinriviera.info/hr/accommodation/mobile-homes/mobilne-kucice-arena-kazela/
# https://www.medulinriviera.info/hr/accommodation/mobile-homes/mobilne-kucice-arena-indije/
# https://www.medulinriviera.info/hr/accommodation/mobile-homes/mobilne-kucice-arena-medulin/
# https://www.medulinriviera.info/hr/accommodation/mobile-homes/mobilne-kucice-arena-stupice/
# https://www.medulinriviera.info/hr/accommodation/mobile-homes/mobilne-kucice-centinera/
# https://www.medulinriviera.info/hr/accommodation/resorts/ai-pini-medulin-resort/
# https://www.medulinriviera.info/hr/accommodation/resorts/residence-superior-del-mar/
# https://www.medulinriviera.info/hr/accommodation/resorts/resort-centinera/
# https://www.medulinriviera.info/hr/accommodation/resorts/apartmani-kazela/
# https://www.medulinriviera.info/hr/accommodation/marinas/aci-marina-pomer/
# https://www.medulinriviera.info/hr/accommodation/marinas/marina-medulin/
# https://www.medulinriviera.info/hr/accommodation/marinas/marina-porto-volme/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartmani-vugrinec/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/tess/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/rakic/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartmani-dujak/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/house-istriana/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/marija/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/kuzzi-1/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartman-luna/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartman-rossa/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/nila/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/loren/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/house-oliva/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/p/2/
# https://www.medulinriviera.info/hr/accommodation/hostel/hostel-erks/
# https://www.medulinriviera.info/hr/places/medulin/
# https://www.medulinriviera.info/hr/places/premantura/
# https://www.medulinriviera.info/hr/places/banjole/
# https://www.medulinriviera.info/hr/places/pomer/
# https://www.medulinriviera.info/hr/places/pjescana-uvala/
# https://www.medulinriviera.info/hr/places/vinkuran/
# https://www.medulinriviera.info/hr/places/vintjan/
# https://www.medulinriviera.info/hr/activities/diving/
# https://www.medulinriviera.info/hr/activities/football/
# https://www.medulinriviera.info/hr/activities/athletics/
# https://www.medulinriviera.info/hr/activities/cycling/
# https://www.medulinriviera.info/hr/activities/tennis/
# https://www.medulinriviera.info/hr/activities/horseback-riding/
# https://www.medulinriviera.info/hr/activities/sailing/
# https://www.medulinriviera.info/hr/activities/kayak-sup/
# https://www.medulinriviera.info/hr/activities/windsurfing-kitesurfing/
# https://www.medulinriviera.info/hr/activities/other-sports-on-water/
# https://www.medulinriviera.info/hr/activities/walking-routes/
# https://www.medulinriviera.info/hr/attraction/arheoloski-park-vizula/
# https://www.medulinriviera.info/hr/attraction/malin-simbol-medulina-i-cuvar-njegovog-porta/
# https://www.medulinriviera.info/hr/attraction/park-povijesti-opcine-medulin/
# https://www.medulinriviera.info/hr/attraction/adrenalinski-park/
# https://www.medulinriviera.info/hr/attraction/jangalooz-pomer/
# https://www.medulinriviera.info/hr/attraction/izleti-brodom/
# https://www.medulinriviera.info/hr/attraction/big-game-fishing/
# https://www.medulinriviera.info/hr/attraction/mini-sub-podvodna-podmornica/
# https://www.medulinriviera.info/hr/attraction/quad-safari/
# https://www.medulinriviera.info/hr/attraction/safari-bar/
# https://www.medulinriviera.info/hr/attraction/istarska-farma/
# https://www.medulinriviera.info/hr/attraction/rt-kamenjak-snorkeling/
# https://www.medulinriviera.info/hr/attractions/page/2/
# https://www.medulinriviera.info/hr/kamenjak/vodeni-edukativni-programi-kamenjak/
# https://www.medulinriviera.info/hr/kamenjak/servisne-informacije-kamenjak/
# https://www.medulinriviera.info/hr/archeological-park-vizula/more-about-vizula/
# https://www.medulinriviera.info/hr/archeological-park-vizula/the-legend-of-crispus/
# https://www.medulinriviera.info/hr/archeological-park-vizula/virtual-reality/
# https://www.medulinriviera.info/hr/archeological-park-vizula/an-archaeological-walk-through-vizula/
# https://www.medulinriviera.info/hr/archeological-park-vizula/map/
# https://www.medulinriviera.info/hr/archeological-park-vizula/brochure/
# https://www.medulinriviera.info/hr/the-magic-of-music/gates-of-agartha/
# https://www.medulinriviera.info/hr/the-magic-of-music/solomun-cave-romane/
# https://www.medulinriviera.info/hr/the-magic-of-music/paul-kalkbrenner-cave-romane/
# https://www.medulinriviera.info/hr/the-magic-of-music/amazing-sound-of-cave-romanae/
# https://www.medulinriviera.info/hr/the-magic-of-music/tear-it-up/
# https://www.medulinriviera.info/hr/the-magic-of-music/hook-cook-festival/
# https://www.medulinriviera.info/hr/the-magic-of-music/vizula-aeterna-festival/
# https://www.medulinriviera.info/hr/the-magic-of-music/medulin-concert-summer/
# https://www.medulinriviera.info/hr/the-magic-of-music/ribarske-klapske-veceri/
# https://www.medulinriviera.info/hr/activity/136-dinasour-trail/
# https://www.medulinriviera.info/hr/attraction/panoramski-letovi/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/adamenko/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/p/3/
# https://www.medulinriviera.info/hr/activity/diving-scuba-libre/
# https://www.medulinriviera.info/hr/activity/diving-centar-indie/
# https://www.medulinriviera.info/hr/21-otvoreni-turnir-zns-a-medulin-2022/
# https://www.medulinriviera.info/hr/activity/gat-2/
# https://www.medulinriviera.info/hr/activity/medulin-riviera/
# https://www.medulinriviera.info/hr/activity/316-premanturka/
# https://www.medulinriviera.info/hr/activity/317-medulinka/
# https://www.medulinriviera.info/hr/activity/318-orhideja/
# https://www.medulinriviera.info/hr/activity/319-banjolka/
# https://www.medulinriviera.info/hr/activity/351-curiositas-histriae/
# https://www.medulinriviera.info/hr/activity/brijuni-riviera/
# https://www.medulinriviera.info/hr/activity/the-east-story/
# https://www.medulinriviera.info/hr/activity/pula-classical/
# https://www.medulinriviera.info/hr/activity/the-amazing-green/
# https://www.medulinriviera.info/hr/activity/357-kamenjak-direct/
# https://www.medulinriviera.info/hr/activity/windsurf-centar-premantura/
# https://www.medulinriviera.info/hr/activity/jistra-adventures/
# https://www.medulinriviera.info/hr/activity/bike-rental-sepe/
# https://www.medulinriviera.info/hr/activity/samys-ranch/
# https://www.medulinriviera.info/hr/activity/ranch-istra-star/
# https://www.medulinriviera.info/hr/activity/adriatic-yacht-charter/
# https://www.medulinriviera.info/hr/activity/clivo-sailing-club/
# https://www.medulinriviera.info/hr/activity/vito-nautika/
# https://www.medulinriviera.info/hr/activity/jistra-adventures-2/
# https://www.medulinriviera.info/hr/activity/windsurfing-tsunami/
# https://www.medulinriviera.info/hr/activity/windsurfing-centar-premantura/
# https://www.medulinriviera.info/hr/activity/windsurfing-centar-medulin/
# https://www.medulinriviera.info/hr/activity/windsurfing-pomer/
# https://www.medulinriviera.info/hr/activity/mediterraneo-beach/
# https://www.medulinriviera.info/hr/activity/jistra-advenrure-ostali-sportovi-na-vodi/
# https://www.medulinriviera.info/hr/activity/on-the-orchid-trail-in-lower-kamenjak-route-no-304/
# https://www.medulinriviera.info/hr/activity/135-way-of-the-cross-trail/
# https://www.medulinriviera.info/hr/activity/138-punta-educational-trail/
# http://www.medulinriviera.info/hr/archeological-park-vizula/
# https://www.medulinriviera.info/hr/attraction/coasteering-pustolovina/
# https://www.medulinriviera.info/hr/attraction/sup-glow-night-tour/
# https://www.medulinriviera.info/hr/attraction/kajakarenje-medulinskim-arhipelagom/
# https://www.medulinriviera.info/hr/attraction/anticka-pula/
# https://www.medulinriviera.info/hr/attraction/istarske-mumije/
# https://www.medulinriviera.info/hr/attraction/nacionalni-park-brijuni/
# https://www.medulinriviera.info/hr/attraction/istratour/
# https://www.medulinriviera.info/hr/attraction/rovinj-lim-fjord/
# https://www.medulinriviera.info/hr/attraction/jama-baredine/
# https://www.medulinriviera.info/hr/attraction/plitvicka-jezera/
# https://www.medulinriviera.info/hr/attraction/venecija/
# http://www.medulinriviera.info/hr/events/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/villa-bilen/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/apafrtment-valsabbion/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartmani-e-d/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/villa-sarchi/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/maja/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/radosevic/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/adria-vista-mare/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartman-rubina/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/gaby/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/jurman/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/house-majovski/
# https://www.medulinriviera.info/hr/accommodation/private-accommodation/p/4/
# {'https://www.medulinriviera.info/hr/accommodation/hotels/', 'https://www.medulinriviera.info/hr/accommodation/camping/kamp-peskera/', 'https://www.medulinriviera.info/hr/activities/athletics/', 'https://www.medulinriviera.info/hr/activities/diving/', 'https://www.medulinriviera.info/hr/activities/horseback-riding/', 'https://www.medulinriviera.info/hr/accommodation/marinas/marina-medulin/', 'https://www.medulinriviera.info/hr/multimedia/', 'https://www.medulinriviera.info/hr/accommodation/resorts/ai-pini-medulin-resort/', 'https://www.medulinriviera.info/hr/attraction/jangalooz-pomer/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/', 'https://www.medulinriviera.info/hr/webcam/', 'https://www.medulinriviera.info/hr/dolazak-u-medulin/', 'https://www.medulinriviera.info/hr/accommodation/mobile-homes/mobilne-kucice-arena-medulin/', 'https://www.medulinriviera.info/hr/attraction/kajakarenje-medulinskim-arhipelagom/', 'https://www.medulinriviera.info/hr/activity/clivo-sailing-club/', 'https://www.medulinriviera.info/hr/activity/windsurf-centar-premantura-2/', 'https://www.medulinriviera.info/hr/accommodation/camping/kamp-arena-runke/', 'https://www.medulinriviera.info/hr/activity/the-big-blue/', 'https://www.medulinriviera.info/hr/activities/cycling/download/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartmani-dujak/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/p/4/', 'https://www.medulinriviera.info/hr/attraction/adrenalinski-park/', 'https://www.medulinriviera.info/hr/home/jesen-i-zima-na-medulin-rivieri/', 'https://www.medulinriviera.info/hr/attraction/izleti-brodom/', 'https://www.medulinriviera.info/hr/attractions/page/2/', 'https://www.medulinriviera.info/hr/accommodation/marinas/', 'https://www.medulinriviera.info/hr/activity/windsurfing-centar-medulin/', 'https://www.medulinriviera.info/hr/places/pjescana-uvala/', 'https://www.medulinriviera.info/hr/activity/gat/', 'https://www.medulinriviera.info/hr/activities/kayak-sup/', 'https://www.medulinriviera.info/hr/activities/cycling/', 'https://www.medulinriviera.info/hr/activity/357-kamenjak-direct/', 'https://www.medulinriviera.info/hr/wi-fi-tocke/', 'https://www.medulinriviera.info/hr/activity/brijuni-riviera/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartman-rossa/', 'https://www.medulinriviera.info/hr/activity/diving-scuba-libre/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/apartmani-vugrinec/', 'https://www.medulinriviera.info/hr/attraction/plitvicka-jezera/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/marija/', 'https://www.medulinriviera.info/hr/activity/318-orhideja/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/jurman/', 'https://www.medulinriviera.info/hr/', 'https://www.medulinriviera.info/hr/archeological-park-vizula/virtual-reality/', 'https://www.medulinriviera.info/hr/navigation-maps/', 'https://www.medulinriviera.info/hr/activity/samys-ranch/', 'https://www.medulinriviera.info/hr/beaches/otoci/', 'https://www.medulinriviera.info/hr/beaches/vinkuran/', 'https://www.medulinriviera.info/hr/activity/medulin-riviera/', 'https://www.medulinriviera.info/hr/activity/jistra-adventures/', 'https://www.medulinriviera.info/hr/activity/rental-center-medulin/', 'https://www.medulinriviera.info/hr/beaches/premantura/', 'https://www.medulinriviera.info/hr/activities/football/', 'https://www.medulinriviera.info/hr/activities/', 'https://www.medulinriviera.info/hr/activity/windsurf-station-premantura/', 'https://www.medulinriviera.info/hr/accommodation/hotels/hotel-sensimar-medulin/', 'https://www.medulinriviera.info/hr/activities/sailing/', 'https://www.medulinriviera.info/hr/topla-zima/', 'https://www.medulinriviera.info/hr/accommodation/private-accommodation/kuzzi-1/', 'https://www.medulinriviera.info/hr/activities/tennis/', 'https://www.medulinriviera.info/hr/the-magic-of- ...

# %%
len(subpages)
# Out:
# 210
